# %% [markdown]
# # Datafetcher

# %% [markdown]
# Fetches data from various sources
#
# ## Kaggle

# %% [markdown]
# import kaggle

# %%
import kaggle
# Out:
# Could not find kaggle.json. Make sure it's located in C:\Users\niels\.kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import kaggle
#
# File c:\Users\niels\Neural network excercise\Neural-network-exercise\.venv\Lib\site-packages\kaggle\__init__.py:10
#       8 enable_oauth = os.environ.get("KAGGLE_ENABLE_OAUTH") in ("1", "true", "yes")
#       9 api = KaggleApi(enable_oauth=enable_oauth)
# ---> 10 api.authenticate()
#
# File c:\Users\niels\Neural network excercise\Neural-network-exercise\.venv\Lib\site-packages\kaggle\api\kaggle_api_extended.py:685, in KaggleApi.authenticate(self)
#     678 else:
#     679     print(
#     680         "Could not find {}. Make sure it's located in"
#     681         " {}. Or use the environment method. See setup"
# ...
